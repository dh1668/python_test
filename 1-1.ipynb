# %% [markdown]
# # Header1
# ## Header2
# ### Header3
# #### Header4

# %% [markdown]
# 목록형
#  - 목록1
#  - 목록2
#  - 목록3
#
# 목록형2
#  - 목록4
#  - 목록5
#  - 목록6

# %% [markdown]
# 숫자 목록
#
#
# 1. 하나
# 2. 둘
# 3. 셋
#
# 숫자2
#
# 1. 하나
# 2. 하나
# 3. 하나
# 4. 하나

# %% [markdown]
# 혼합
#
#  - 리스트
#    -  목록1
#    -  목록2
#  - 리스트2
#    1. 숫자1
#    2. 숫자2
#        - 목록3
#        - 목록4

# %% [markdown]
# 코드 표시!
# ```
# print("안녕하세요 파이썬 프로그래밍 과정!!!")
# ```

# %% [markdown]
# 코드 표시!
# ```python
# print("안녕하세요 파이썬 프로그래밍 과정!!!")
# ```

# %% [markdown]
# ### 이미지 링크!
#
# 마크다운 방식: `![](https://media.vlpt.us/images/limsw/post/388c1502-5312-4b5a-a17e-299490471f5b/python.png)`
#
# ![](https://media.vlpt.us/images/limsw/post/388c1502-5312-4b5a-a17e-299490471f5b/python.png)

# %% [markdown]
# HTML방식 - 이미지 크기 조정!
#
# <img src="https://media.vlpt.us/images/limsw/post/388c1502-5312-4b5a-a17e-299490471f5b/python.png"
#      width=150>

# %% [markdown]
# raw 방식:
#
#
# ![image.png](attachment:image.png)

# %%
print("안녕하세요 파이썬 프로그래밍 과정!!!")
# Out:
# 안녕하세요 파이썬 프로그래밍 과정!!!

# %%
msg = "안녕하세요 파이썬 프로그래밍 과정!!!"
print(msg)
# Out:
# 안녕하세요 파이썬 프로그래밍 과정!!!

# %%
print(100000**10000)
# Out:
# ...

# %% [markdown]
# ### 이미지 링크!
# ![image.png](attachment:a980a9fe-3dba-4a7f-847e-51ad605f0502.png)
